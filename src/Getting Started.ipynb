# %% [markdown]
# # Getting Started: 	Stability Analysis of Multivariable Digital Control Systems with Uncertain Timing
# This is a Jupyter notebook in which you can interactively try out everything.
# If you are new to Jupyter notebooks, have a look at https://nbviewer.jupyter.org/github/ipython/ipython/blob/3.x/examples/Notebook/Index.ipynb , try your luck with "Cell - Run all Cells", or simply read through the commands and the output (which was saved from the last time this notebook was run).

# %%
import sys
sys.path.append('.')
import numpy as np
from qronos.controlloop import DigitalControlLoop
from qronos import examples
from qronos.lis import analyze

# %% [markdown]
# ## Note for changing code
# If you changed code outside of this notebook, use Kernel - Restart.

# %% [markdown]
# ## Example 1: Stability analysis for a predefined example
# A number of examples is predefined in [qronos/examples.py](/edit/qronos/examples.py). The publication uses `examples.example_C_quadrotor_attitude_one_axis()` and `examples.example_D_quadrotor_attitude_three_axis()`.

# %%
sys1 = examples.example_A1_stable_1()
analyze.analyze(sys1)
# Out:
# Analyzing system: System(
#    A_d = array([[-0.01]])
#    A_p = array([[0.05]])
#    B_d = array([[-0.4]])
#    B_p = array([[0.5]])
#    C_d = array([[1]])
#    C_p = array([[1]])
#    T = 1
#    delta_t_u_max = array([0.002])
#    delta_t_u_min = array([-0.001])
#    delta_t_y_max = array([0.002])
#    delta_t_y_min = array([-0.1])
#    global_time = False
#    results = {}
#    spaceex_clustering_percent = 100
#    spaceex_directions = 'oct'
#    spaceex_iterations = 200
#    spaceex_iterations_for_global_time = None
#    spaceex_only_simulate = False
#    spaceex_sampling_time = 0.001
#    spaceex_scenario = 'stc'
#    spaceex_set_aggregation = 'none'
#    transform_states_as_outputs = False
#    use_urgent_semantics_and_pseudorandom_sequence = False
#    x_p_0_max = array([1])
#    x_p_0_min = array([-1]))
# Please note that some of the above parameters, eg. spaceex_... are not used in this LMI-based analysis, they are only present for reachability analysis.
# [mpf('0.0'), mpf('0.79720326050580215'), mpf('3.3684197648352837e-16'), mpf('0.24406783587022149')]
# spectral radius(A) =  0.797203260505802
# interval spectral_norm(A) =  [1.587321574233183652, 1.5873215742331865385]
# tightening rho= 0.8
# precondition= True
# beta= 4.62285538879101
#
# Solving CQLF LMI
# Iteration 0 of 3: delta=2, beta=4.62285538879101
# Solving CQLF for preconditioning (result may be cached)
#      pcost       dcost       gap    pres   dres   k/t
#  0: -2.7968e-01 -5.3034e+00  3e+01  3e+00  6e+00  1e+00
#  1: -3.8885e-01 -5.0585e-01  1e+00  4e-01  8e-01  7e-01
#  2: -2.4653e-01 -2.8046e-01  2e-01  7e-02  2e-01  1e-01
#  3: -2.1819e-01 -2.2374e-01  2e-02  8e-03  2e-02  1e-02
#  4: -2.1492e-01 -2.1579e-01  2e-03  6e-04  1e-03  5e-04
#  5: -2.1451e-01 -2.1454e-01  8e-05  2e-05  5e-05  2e-05
#  6: -2.1450e-01 -2.1450e-01  6e-06  2e-06  4e-06  2e-06
#  7: -2.1450e-01 -2.1450e-01  4e-07  9e-08  2e-07  2e-08
#  8: -2.1450e-01 -2.1450e-01  1e-08  3e-09  6e-09  6e-10
# Optimal solution found.
# (transformed) robustness gamma: [0.21450216]
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.2430e-01 -5.3837e+00  8e+01  4e+00  6e+00  1e+00
#  1: -6.0697e-01 -1.0813e+00  6e+00  8e-01  1e+00  8e-01
#  2: -5.3618e-01 -7.7666e-01  2e+00  3e-01  5e-01  3e-01
#  3: -3.8389e-01 -4.5792e-01  4e-01  7e-02  1e-01  4e-02
#  4: -3.6263e-01 -4.2980e-01  3e-01  6e-02  9e-02  3e-02
#  5: -3.1095e-01 -3.2096e-01  4e-02  8e-03  1e-02  3e-03
#  6: -3.0515e-01 -3.0913e-01  1e-02  3e-03  4e-03  6e-04
#  7: -3.0323e-01 -3.0427e-01  3e-03  8e-04  1e-03  1e-04
#  8: -3.0241e-01 -3.0260e-01  6e-04  1e-04  2e-04  2e-05
#  9: -3.0226e-01 -3.0227e-01  4e-05  9e-06  1e-05  1e-06
# 10: -3.0225e-01 -3.0225e-01  3e-06  6e-07  9e-07  1e-07
# 11: -3.0225e-01 -3.0225e-01  1e-07  3e-08  5e-08  5e-09
# Optimal solution found.
# (transformed) robustness gamma: [0.30225059]
# Solving CQLF for beta= 4.62285538879101  resulted in robustness gamma= [0.30225059]
# first approximation:
# approx P_norm(A) =  0.8377626170209265
# u 0:
# sampled P_norm(...expm(...)...) =  0.003035298076154543
# y 0:
# sampled P_norm(...expm(...)...) =  0.07086688639045644
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.0025671357897400454
# approx rho= 0.9142319372772775
# Iteration 1 of 3: delta=2, beta=4.35789338724547
# Solving CQLF for preconditioning (result may be cached)
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.2368e-01 -5.3826e+00  8e+01  4e+00  6e+00  1e+00
#  1: -6.1389e-01 -1.1085e+00  6e+00  8e-01  1e+00  8e-01
#  2: -5.4295e-01 -7.9358e-01  2e+00  3e-01  5e-01  3e-01
#  3: -3.8389e-01 -4.5845e-01  4e-01  7e-02  1e-01  4e-02
#  4: -3.6381e-01 -4.3215e-01  3e-01  6e-02  1e-01  3e-02
#  5: -3.1108e-01 -3.2114e-01  4e-02  8e-03  1e-02  3e-03
#  6: -3.0518e-01 -3.0913e-01  1e-02  3e-03  4e-03  6e-04
#  7: -3.0327e-01 -3.0435e-01  3e-03  8e-04  1e-03  2e-04
#  8: -3.0242e-01 -3.0261e-01  6e-04  1e-04  2e-04  2e-05
#  9: -3.0226e-01 -3.0227e-01  4e-05  8e-06  1e-05  1e-06
# 10: -3.0225e-01 -3.0225e-01  2e-06  5e-07  8e-07  8e-08
# 11: -3.0225e-01 -3.0225e-01  1e-07  3e-08  5e-08  5e-09
# Optimal solution found.
# (transformed) robustness gamma: [0.30225059]
# Solving CQLF for beta= 4.35789338724547  resulted in robustness gamma= [0.30225059]
# first approximation:
# approx P_norm(A) =  0.8377626161293881
# u 0:
# sampled P_norm(...expm(...)...) =  0.003035171072776366
# y 0:
# sampled P_norm(...expm(...)...) =  0.07088159396865636
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.002567947388008566
# approx rho= 0.9142473285588294
# Iteration 2 of 3: delta=2, beta=4.10894473973346
# Solving CQLF for preconditioning (result may be cached)
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.2291e-01 -5.3812e+00  8e+01  4e+00  6e+00  1e+00
#  1: -6.2104e-01 -1.1349e+00  6e+00  8e-01  1e+00  8e-01
#  2: -5.4891e-01 -8.0892e-01  2e+00  3e-01  5e-01  3e-01
#  3: -3.8375e-01 -4.5847e-01  4e-01  7e-02  1e-01  4e-02
#  4: -3.6458e-01 -4.3363e-01  3e-01  6e-02  1e-01  3e-02
#  5: -3.1135e-01 -3.2160e-01  4e-02  8e-03  1e-02  3e-03
#  6: -3.0522e-01 -3.0918e-01  1e-02  3e-03  5e-03  6e-04
#  7: -3.0330e-01 -3.0441e-01  4e-03  8e-04  1e-03  2e-04
#  8: -3.0243e-01 -3.0263e-01  6e-04  1e-04  2e-04  2e-05
#  9: -3.0226e-01 -3.0227e-01  4e-05  8e-06  1e-05  1e-06
# 10: -3.0225e-01 -3.0225e-01  2e-06  5e-07  7e-07  8e-08
# 11: -3.0225e-01 -3.0225e-01  1e-07  3e-08  4e-08  5e-09
# Optimal solution found.
# (transformed) robustness gamma: [0.30225059]
# Solving CQLF for beta= 4.10894473973346  resulted in robustness gamma= [0.30225059]
# first approximation:
# approx P_norm(A) =  0.8377626158745709
# u 0:
# sampled P_norm(...expm(...)...) =  0.003035135247781568
# y 0:
# sampled P_norm(...expm(...)...) =  0.070887530691934
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.002568275378804066
# approx rho= 0.9142535571930905
# Results:
# rho (approx.): 0.9142319372772775  for  beta: 4.62285538879101  with robustness gamma: [0.30225059]
# Eccentricity alpha (approx): 2.7165415961156514
# rho (approx.): 0.9142473285588294  for  beta: 4.35789338724547  with robustness gamma: [0.30225059]
# Eccentricity alpha (approx): 2.7160763035146345
# rho (approx.): 0.9142535571930905  for  beta: 4.10894473973346  with robustness gamma: [0.30225059]
# Eccentricity alpha (approx): 2.715897002753009
# Best rho (approx):  0.9142319372772775
# Exact results:
# interval P_norm(A) =  [0.83776261702092413852, 0.83776261702093057782]
# u 0:
# interval P_norm(...expm(...)) =  [0.0, 0.0030352980761547639944]
# sampled P_norm(...expm(...)) =  0.003035298076154543
# y 0:
# interval P_norm(...expm(...)) =  [0.0, 0.070866886390457600742]
# sampled P_norm(...expm(...)) =  0.07086688639045644
# u 0 combined with y 0:
# interval P_norm(...expm(...)) =  [0.0, 0.0025671357897401199909]
# sampled P_norm(...expm(...)) =  0.0025671357897400454
# Overall rho:  [0.83776261702092413852, 0.91423193727728324642]
# {'n': 4,
#  'rho': 0.914232028700477,
#  'rho_approx': 0.9142319372772775,
#  'time': 1.933891,
#  'time_approx': 1.174332}

# %% [markdown]
# ## Example 2: Modifying a predefined example

# %%
# For comparison, the original example
sys2 = examples.example_C_quadrotor_attitude_one_axis()
result2 = analyze.analyze(sys2)
# Out:
# Analyzing system: System(
#    A_d = array([[1, 0],
#                 [0, 0]])
#    A_p = array([[0]])
#    B_d = array([[0.01],
#                 [1.  ]])
#    B_p = array([[110669.66212552]])
#    C_d = array([[-0.0036144 , -0.00025557]])
#    C_p = array([[1]])
#    T = 0.01
#    delta_t_u_max = array([0.0001])
#    delta_t_u_min = array([-0.0001])
#    delta_t_y_max = array([0.0001])
#    delta_t_y_min = array([-0.0001])
#    global_time = False
#    results = {}
#    spaceex_clustering_percent = 100
#    spaceex_directions = 'oct'
#    spaceex_iterations = 8500
#    spaceex_iterations_for_global_time = None
#    spaceex_only_simulate = False
#    spaceex_sampling_time = 0.001
#    spaceex_scenario = 'stc'
#    spaceex_set_aggregation = 'none'
#    transform_states_as_outputs = False
#    use_urgent_semantics_and_pseudorandom_sequence = False
#    x_p_0_max = array([1])
#    x_p_0_min = array([-1]))
# Please note that some of the above parameters, eg. spaceex_... are not used in this LMI-based analysis, they are only present for reachability analysis.
# [mpf('0.78270111788536034'), mpf('0.78270111788535957'), mpf('5.4745810846128191e-16'), mpf('8.2936438327266769e-16'), mpf('0.46168583358214854')]
# spectral radius(A) =  0.78270111788536
# interval spectral_norm(A) =  [958.44561914009341308, 958.44561914009523207]
# tightening rho= 0.8
# precondition= True
# beta= 4.31433420584928
#
# Solving CQLF LMI
# Iteration 0 of 3: delta=2, beta=4.31433420584928
# Solving CQLF for preconditioning (result may be cached)
#      pcost       dcost       gap    pres   dres   k/t
#  0: -2.1344e-01 -6.2246e+00  4e+01  2e+00  1e+06  1e+00
#  1: -1.5790e-01 -3.7885e-01  1e+00  3e-01  2e+05  7e-01
#  2: -8.2962e-03 -4.3396e-02  1e-01  2e-02  1e+04  3e-02
#  3: -1.4891e-03 -1.1423e-02  2e-02  5e-03  3e+03  4e-03
#  4: -1.1371e-03 -9.8719e-03  3e-02  4e-03  2e+03  3e-03
#  5: -2.0477e-04 -1.7474e-03  4e-03  7e-04  4e+02  5e-04
#  6: -5.4293e-05 -5.1784e-04  1e-03  2e-04  1e+02  8e-05
#  7: -1.2565e-05 -1.2826e-04  3e-04  5e-05  3e+01  2e-05
#  8: -3.2088e-06 -3.4392e-05  8e-05  1e-05  7e+00  5e-06
#  9: -1.0972e-06 -8.0377e-06  2e-05  3e-06  2e+00  8e-07
# 10: -6.7906e-07 -2.4723e-06  4e-06  7e-07  4e-01  2e-07
# 11: -5.4645e-07 -1.0940e-06  1e-06  2e-07  1e-01  5e-08
# 12: -5.9260e-07 -6.9495e-07  2e-07  4e-08  2e-02  9e-09
# 13: -5.8947e-07 -6.0765e-07  3e-08  7e-09  4e-03  1e-09
# 14: -5.9110e-07 -5.9303e-07  3e-09  7e-10  4e-04  2e-10
# 15: -5.9124e-07 -5.9176e-07  8e-10  2e-10  1e-04  4e-11
# 16: -5.9125e-07 -5.9130e-07  8e-11  2e-11  1e-05  4e-12
# 17: -5.9125e-07 -5.9125e-07  7e-12  3e-12  9e-07  3e-13
# 18: -5.9125e-07 -5.9125e-07  4e-13  6e-12  5e-08  2e-14
# Optimal solution found.
# (transformed) robustness gamma: [5.91247501e-07]
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.4733e-01 -6.4701e+00  9e+01  4e+00  7e+00  1e+00
#  1: -5.6659e-01 -9.9873e-01  6e+00  8e-01  1e+00  9e-01
#  2: -2.0025e-01 -5.0680e-01  3e+00  4e-01  6e-01  4e-01
#  3: -1.2161e-01 -2.1576e-01  5e-01  8e-02  1e-01  5e-02
#  4: -9.6534e-02 -1.5055e-01  2e-01  4e-02  7e-02  2e-02
#  5: -7.7585e-02 -1.1248e-01  1e-01  3e-02  4e-02  1e-02
#  6: -5.9101e-02 -6.9549e-02  3e-02  7e-03  1e-02  2e-03
#  7: -5.3277e-02 -5.5906e-02  8e-03  2e-03  3e-03  2e-04
#  8: -5.1669e-02 -5.2160e-02  1e-03  3e-04  5e-04  3e-05
#  9: -5.1346e-02 -5.1434e-02  3e-04  5e-05  9e-05  5e-06
# 10: -5.1266e-02 -5.1269e-02  6e-06  1e-06  2e-06  1e-07
# 11: -5.1265e-02 -5.1265e-02  1e-06  2e-07  4e-07  2e-08
# 12: -5.1265e-02 -5.1265e-02  3e-07  5e-08  9e-08  5e-09
# 13: -5.1264e-02 -5.1264e-02  9e-09  2e-09  3e-09  2e-10
# Optimal solution found.
# (transformed) robustness gamma: [0.05126445]
# Solving CQLF for beta= 4.31433420584928  resulted in robustness gamma= [0.05126445]
# first approximation:
# approx P_norm(A) =  0.8261608986973614
# u 0:
# sampled P_norm(...expm(...)...) =  0.07715664634398765
# y 0:
# sampled P_norm(...expm(...)...) =  0.07602117620540205
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.12308857656025508
# approx rho= 1.1024272978070062
# Iteration 1 of 3: delta=2, beta=13.7127443328247
# Solving CQLF for preconditioning (result may be cached)
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.4998e-01 -6.4750e+00  9e+01  4e+00  6e+00  1e+00
#  1: -4.7198e-01 -5.6173e-01  4e+00  5e-01  8e-01  9e-01
#  2: -1.3795e-01 -2.6819e-01  2e+00  2e-01  3e-01  3e-01
#  3: -8.7716e-02 -1.2296e-01  3e-01  3e-02  5e-02  3e-02
#  4: -6.2936e-02 -8.3424e-02  2e-01  2e-02  3e-02  1e-02
#  5: -4.5201e-02 -5.2121e-02  4e-02  5e-03  7e-03  2e-03
#  6: -3.8288e-02 -4.1144e-02  1e-02  2e-03  3e-03  6e-04
#  7: -3.4926e-02 -3.5456e-02  2e-03  3e-04  5e-04  8e-05
#  8: -3.4536e-02 -3.4919e-02  2e-03  2e-04  4e-04  5e-05
#  9: -3.3834e-02 -3.3846e-02  5e-05  7e-06  1e-05  1e-06
# 10: -3.3815e-02 -3.3815e-02  3e-06  5e-07  7e-07  7e-08
# 11: -3.3813e-02 -3.3814e-02  1e-06  2e-07  3e-07  3e-08
# 12: -3.3813e-02 -3.3813e-02  6e-08  9e-09  1e-08  1e-09
# Optimal solution found.
# (transformed) robustness gamma: [0.03381283]
# Solving CQLF for beta= 13.7127443328247  resulted in robustness gamma= [0.03381283]
# first approximation:
# approx P_norm(A) =  0.8261609192254692
# u 0:
# sampled P_norm(...expm(...)...) =  0.038282736717292
# y 0:
# sampled P_norm(...expm(...)...) =  0.036999399124051674
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.05929447485779354
# approx rho= 0.9607375299246064
# Iteration 2 of 3: delta=2, beta=21.2312979046277
# Solving CQLF for preconditioning (result may be cached)
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.4996e-01 -6.4749e+00  9e+01  4e+00  6e+00  1e+00
#  1: -4.6353e-01 -5.4201e-01  4e+00  5e-01  8e-01  9e-01
#  2: -1.2798e-01 -2.4162e-01  2e+00  2e-01  3e-01  2e-01
#  3: -7.9057e-02 -1.0474e-01  3e-01  3e-02  5e-02  3e-02
#  4: -5.8401e-02 -7.5294e-02  2e-01  2e-02  3e-02  2e-02
#  5: -3.9970e-02 -5.1238e-02  9e-02  9e-03  1e-02  5e-03
#  6: -2.9659e-02 -3.5885e-02  5e-02  4e-03  7e-03  2e-03
#  7: -2.3344e-02 -2.5088e-02  9e-03  1e-03  2e-03  1e-04
#  8: -2.0502e-02 -2.0881e-02  2e-03  2e-04  3e-04  3e-05
#  9: -2.0376e-02 -2.0730e-02  2e-03  2e-04  3e-04  4e-05
# 10: -1.9542e-02 -1.9590e-02  3e-04  3e-05  4e-05  4e-06
# 11: -1.9464e-02 -1.9490e-02  1e-04  2e-05  2e-05  2e-06
# 12: -1.9388e-02 -1.9389e-02  7e-06  8e-07  1e-06  1e-07
# 13: -1.9384e-02 -1.9384e-02  1e-06  1e-07  2e-07  2e-08
# 14: -1.9384e-02 -1.9384e-02  2e-07  2e-08  3e-08  3e-09
# 15: -1.9383e-02 -1.9383e-02  3e-08  3e-09  5e-09  5e-10
# Optimal solution found.
# (transformed) robustness gamma: [0.01938349]
# Solving CQLF for beta= 21.2312979046277  resulted in robustness gamma= [0.01938349]
# first approximation:
# approx P_norm(A) =  0.8261609062324176
# u 0:
# sampled P_norm(...expm(...)...) =  0.025351647860913727
# y 0:
# sampled P_norm(...expm(...)...) =  0.024165144356294892
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.038126579453671705
# approx rho= 0.9138042779032979
# Results:
# rho (approx.): 1.1024272978070062  for  beta: 4.31433420584928  with robustness gamma: [0.05126445]
# Eccentricity alpha (approx): 927.2579546651887
# rho (approx.): 0.9607375299246064  for  beta: 13.7127443328247  with robustness gamma: [0.03381283]
# Eccentricity alpha (approx): 1352.6242753293152
# rho (approx.): 0.9138042779032979  for  beta: 21.2312979046277  with robustness gamma: [0.01938349]
# Eccentricity alpha (approx): 1687.1421895830217
# Best rho (approx):  0.9138042779032979
# Exact results:
# interval P_norm(A) =  [0.82616090623241100754, 0.82616090623242510738]
# u 0:
# interval P_norm(...expm(...)) =  [0.0, 0.025351647860914247601]
# sampled P_norm(...expm(...)) =  0.025351647860913727
# y 0:
# interval P_norm(...expm(...)) =  [0.0, 0.02416514435631765545]
# sampled P_norm(...expm(...)) =  0.024165144356294892
# u 0 combined with y 0:
# interval P_norm(...expm(...)) =  [0.0, 0.038126579453672600206]
# sampled P_norm(...expm(...)) =  0.038126579453671705
# Overall rho:  [0.82616090623241100754, 0.91380427790332974247]

# %%
# Modify some parameters
sys2 = examples.example_C_quadrotor_attitude_one_axis()
sys2.increase_timing(5) # increase timing by factor five
# sys2.delta_t_u_max = np.array([0.00001]) # modify timing (absolute value in seconds)
# sys2.increase_dimension(2) # double dimension
result2_new = analyze.analyze(sys2) ## Note that this may take ~20 seconds
# Out:
# Analyzing system: System(
#    A_d = array([[1, 0],
#                 [0, 0]])
#    A_p = array([[0]])
#    B_d = array([[0.01],
#                 [1.  ]])
#    B_p = array([[110669.66212552]])
#    C_d = array([[-0.0036144 , -0.00025557]])
#    C_p = array([[1]])
#    T = 0.01
#    delta_t_u_max = array([0.0005])
#    delta_t_u_min = array([-0.0005])
#    delta_t_y_max = array([0.0005])
#    delta_t_y_min = array([-0.0005])
#    global_time = False
#    m = 1
#    n_d = 2
#    n_p = 1
#    p = 1
#    results = {}
#    spaceex_clustering_percent = 100
#    spaceex_directions = 'oct'
#    spaceex_iterations = 8500
#    spaceex_iterations_for_global_time = None
#    spaceex_only_simulate = False
#    spaceex_sampling_time = 0.001
#    spaceex_scenario = 'stc'
#    spaceex_set_aggregation = 'none'
#    transform_states_as_outputs = False
#    use_urgent_semantics_and_pseudorandom_sequence = False
#    x_p_0_max = array([1])
#    x_p_0_min = array([-1]))
# Please note that some of the above parameters, eg. spaceex_... are not used in this LMI-based analysis, they are only present for reachability analysis.
# [mpf('0.78270111788536034'), mpf('0.78270111788535957'), mpf('5.4745810846128191e-16'), mpf('8.2936438327266769e-16'), mpf('0.46168583358214854')]
# spectral radius(A) =  0.78270111788536
# interval spectral_norm(A) =  [958.44561914009341308, 958.44561914009523207]
# tightening rho= 0.8
# precondition= True
# beta= 4.31433420584928
#
# Solving CQLF LMI
# Iteration 0 of 3: delta=2, beta=4.31433420584928
# Solving CQLF for preconditioning (result may be cached)
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -2.9152e-01 -6.3678e+00  9e+01  4e+00  9e+00  1e+00
#  1: -2.3013e-01 -5.2691e-01  5e+00  6e-01  1e+00  7e-01
#  2: -5.8467e-02 -1.9643e-01  7e-01  1e-01  2e-01  5e-02
#  3: -3.3705e-02 -7.2991e-02  1e-01  3e-02  6e-02  1e-02
#  4: -2.6958e-02 -5.8535e-02  1e-01  2e-02  5e-02  8e-03
#  5: -2.2001e-02 -2.8341e-02  2e-02  4e-03  9e-03  9e-04
#  6: -1.9341e-02 -2.0484e-02  3e-03  7e-04  1e-03  5e-05
#  7: -1.8953e-02 -1.9021e-02  2e-04  4e-05  9e-05  3e-06
#  8: -1.8923e-02 -1.8928e-02  1e-05  3e-06  7e-06  2e-07
#  9: -1.8921e-02 -1.8922e-02  2e-06  6e-07  1e-06  4e-08
# 10: -1.8920e-02 -1.8920e-02  2e-07  5e-08  1e-07  3e-09
# 11: -1.8920e-02 -1.8920e-02  2e-08  5e-09  1e-08  3e-10
# Optimal solution found.
# (transformed) robustness gamma: [0.01892021]
# Solving CQLF for beta= 4.31433420584928  resulted in robustness gamma= [0.01892021]
# first approximation:
# approx P_norm(A) =  0.8261609124345718
# u 0:
# sampled P_norm(...expm(...)...) =  0.1248876858470238
# y 0:
# sampled P_norm(...expm(...)...) =  0.11899556484368763
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.18759619301360506
# approx rho= 1.2576403561388882
# Iteration 1 of 3: delta=2, beta=21.4168924741246
# Solving CQLF for preconditioning (result may be cached)
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -2.8804e-01 -6.3614e+00  9e+01  4e+00  9e+00  1e+00
#  1: -1.6370e-01 -3.9970e-01  4e+00  5e-01  1e+00  7e-01
#  2: -1.1125e-02 -4.9963e-02  3e-01  4e-02  9e-02  4e-02
#  3: -2.2007e-03 -1.4058e-02  8e-02  1e-02  2e-02  7e-03
#  4: -1.4052e-03 -6.7845e-03  2e-02  3e-03  7e-03  2e-04
#  5: -1.1207e-03 -2.6518e-03  5e-03  9e-04  2e-03  7e-05
#  6: -9.9780e-04 -2.9610e-03  2e-02  1e-03  3e-03  2e-04
#  7: -5.2884e-04 -1.3379e-03  5e-03  5e-04  1e-03  5e-05
#  8: -6.1448e-05 -1.4142e-04  8e-04  5e-05  1e-04  1e-05
#  9: -6.2803e-07 -1.4511e-06  8e-06  6e-07  1e-06  1e-07
# 10: -6.2841e-09 -1.4520e-08  8e-08  6e-09  1e-08  1e-09
# Optimal solution found.
# (transformed) robustness gamma: [6.28411971e-09]
# Solving CQLF for beta= 21.4168924741246  resulted in robustness gamma= [6.28411971e-09]
# first approximation:
# approx P_norm(A) =  0.9334994447367241
# u 0:
# sampled P_norm(...expm(...)...) =  0.03187639623775478
# y 0:
# sampled P_norm(...expm(...)...) =  0.041550412330617896
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.04856457090347048
# approx rho= 1.0554908242085672
# Iteration 2 of 3: delta=0.9, beta=35.3592330457618
# Solving CQLF for preconditioning (result may be cached)
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -2.8790e-01 -6.3611e+00  9e+01  4e+00  9e+00  1e+00
#  1: -1.6178e-01 -3.9606e-01  4e+00  5e-01  1e+00  7e-01
#  2: -9.5933e-03 -4.4875e-02  3e-01  4e-02  9e-02  3e-02
#  3: -1.4350e-03 -1.0884e-02  8e-02  1e-02  2e-02  8e-03
#  4: -6.8450e-04 -4.9640e-03  2e-02  3e-03  6e-03  8e-04
#  5: -5.1560e-04 -2.6262e-03  1e-02  2e-03  3e-03  5e-04
#  6: -5.4533e-05 -3.9017e-04  2e-03  2e-04  4e-04  2e-05
#  7: -6.5578e-07 -4.5223e-06  2e-05  2e-06  5e-06  2e-07
#  8: -6.5573e-09 -4.5219e-08  2e-07  2e-08  5e-08  2e-09
#  9: -6.5575e-11 -4.5221e-10  2e-09  2e-10  5e-10  2e-11
# Optimal solution found.
# (transformed) robustness gamma: [6.55749523e-11]
# Solving CQLF for beta= 35.3592330457618  resulted in robustness gamma= [6.55749523e-11]
# first approximation:
# approx P_norm(A) =  1.869176167987692
# u 0:
# sampled P_norm(...expm(...)...) =  0.040630301904524685
# y 0:
# sampled P_norm(...expm(...)...) =  0.021863757811583028
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.037139644617613876
# approx rho= 1.9688098723214136
# finding CQLF failed, retrying with lower beta. Probably this system is impossible to verify.
# Results:
# rho (approx.): 1.2576403561388882  for  beta: 4.31433420584928  with robustness gamma: [0.01892021]
# Eccentricity alpha (approx): 1700.6238653961707
# rho (approx.): 1.0554908242085672  for  beta: 21.4168924741246  with robustness gamma: [6.28411971e-09]
# Eccentricity alpha (approx): 1482145.4156989218
# rho (approx.): 1.9688098723214136  for  beta: 35.3592330457618  with robustness gamma: [6.55749523e-11]
# Eccentricity alpha (approx): 14751359.535341417
# Best rho (approx):  1.0554908242085672
# Cannot show stability. Returning approximate result for instability, skipping verification.

# %%
# Compare the results: (Note that result['rho'] is only available if stability can actually be shown.)
print(result2['rho_approx'])
print(result2_new['rho_approx'])
# Out:
# 0.9138042779032979
# 1.0554908242085672

# %% [markdown]
# ## Example 3: Custom system

# %%
# The numbers in this example are randomly made up and don't make too much sense, so do the analysis results.

system=DigitalControlLoop()
# plant with three states, completely stable
system.A_p = np.array([[-1,0,0],[0,-2,0],[0,0,-3]])
# two inputs
system.B_p = np.array([[1,2],[3,4],[5,6]])/10000.
# one output
system.C_p = np.array([[1, 1, 1]])

# The following two lines are not used yet; in the future they will be used to show a simulation.
system.x_p_0_min = np.array([-1,-1,-1]) # minimum initial state, dimension must match the dimension of A
system.x_p_0_max = np.array([+1,+1,+1]) # maximum initial state, dimension must match the dimension of A

# some controller that does not make too much sense (just "random" numbers)
system.A_d = np.array([[0.019,0.020], [0.021,0.022]])
system.B_d = np.array([[0.023], [0.024]])
system.C_d = np.array([[0.025,0.026], [0.027,0.028]])

# period
system.T=2

# timing deviations
system.delta_t_u_min=np.array([-0.1,-0.2])*system.T
system.delta_t_u_max=np.array([0.1,0.2])*system.T
system.delta_t_y_min=np.array([-0.3])*system.T
system.delta_t_y_max=np.array([0.3])*system.T

# %%
system
# Out:
# System(
#    A_d = array([[0.019, 0.02 ],
#                 [0.021, 0.022]])
#    A_p = array([[-1,  0,  0],
#                 [ 0, -2,  0],
#                 [ 0,  0, -3]])
#    B_d = array([[0.023],
#                 [0.024]])
#    B_p = array([[0.0001, 0.0002],
#                 [0.0003, 0.0004],
#                 [0.0005, 0.0006]])
#    C_d = array([[0.025, 0.026],
#                 [0.027, 0.028]])
#    C_p = array([[1, 1, 1]])
#    T = 2
#    delta_t_u_max = array([0.2, 0.4])
#    delta_t_u_min = array([-0.2, -0.4])
#    delta_t_y_max = array([0.6])
#    delta_t_y_min = array([-0.6])
#    global_time = False
#    results = {}
#    spaceex_clustering_percent = 100
#    spaceex_directions = 'oct'
#    spaceex_iterations = 2000
#    spaceex_iterations_for_global_time = None
#    spaceex_only_simulate = False
#    spaceex_sampling_time = 0.001
#    spaceex_scenario = 'stc'
#    spaceex_set_aggregation = 'none'
#    transform_states_as_outputs = False
#    use_urgent_semantics_and_pseudorandom_sequence = False
#    x_p_0_max = array([1, 1, 1])
#    x_p_0_min = array([-1, -1, -1]))

# %%
result = analyze.analyze(system)
# Out:
# Analyzing system: System(
#    A_d = array([[0.019, 0.02 ],
#                 [0.021, 0.022]])
#    A_p = array([[-1,  0,  0],
#                 [ 0, -2,  0],
#                 [ 0,  0, -3]])
#    B_d = array([[0.023],
#                 [0.024]])
#    B_p = array([[0.0001, 0.0002],
#                 [0.0003, 0.0004],
#                 [0.0005, 0.0006]])
#    C_d = array([[0.025, 0.026],
#                 [0.027, 0.028]])
#    C_p = array([[1, 1, 1]])
#    T = 2
#    delta_t_u_max = array([0.2, 0.4])
#    delta_t_u_min = array([-0.2, -0.4])
#    delta_t_y_max = array([0.6])
#    delta_t_y_min = array([-0.6])
#    global_time = False
#    results = {}
#    spaceex_clustering_percent = 100
#    spaceex_directions = 'oct'
#    spaceex_iterations = 2000
#    spaceex_iterations_for_global_time = None
#    spaceex_only_simulate = False
#    spaceex_sampling_time = 0.001
#    spaceex_scenario = 'stc'
#    spaceex_set_aggregation = 'none'
#    transform_states_as_outputs = False
#    use_urgent_semantics_and_pseudorandom_sequence = False
#    x_p_0_max = array([1, 1, 1])
#    x_p_0_min = array([-1, -1, -1]))
# Please note that some of the above parameters, eg. spaceex_... are not used in this LMI-based analysis, they are only present for reachability analysis.
# [mpf('0.1353387542791957'), mpf('0.041076005191176088'), mpf('0.01829674916127837'), mpf('0.0024669199456204844'), mpf('4.8754275257594639e-5'), mpf('1.1797125416231742e-16'), mpf('1.068118387501119e-18'), mpf('5.7763811463021099e-18')]
# spectral radius(A) =  0.135338754279196
# interval spectral_norm(A) =  [0.41525994046709202578, 0.41525994046709313601]
# tightening rho= 0.8
# precondition= True
# beta= 1.80706607094141
#
# Solving CQLF LMI
# Iteration 0 of 3: delta=2, beta=1.80706607094141
# Solving CQLF for preconditioning (result may be cached)
#      pcost       dcost       gap    pres   dres   k/t
#  0: -2.8967e-01 -9.4360e+00  1e+01  8e-10  1e+01  1e+00
#  1: -3.2400e-01 -8.3780e-01  7e-01  5e-11  6e-01  7e-02
#  2: -9.5941e-01 -1.0471e+00  2e-01  9e-12  1e-01  2e-02
#  3: -9.9936e-01 -1.0004e+00  2e-03  1e-13  1e-03  3e-04
#  4: -9.9999e-01 -1.0000e+00  2e-05  3e-15  1e-05  3e-06
#  5: -1.0000e+00 -1.0000e+00  2e-07  2e-15  1e-07  3e-08
#  6: -1.0000e+00 -1.0000e+00  2e-09  2e-15  1e-09  3e-10
# Optimal solution found.
# (transformed) robustness gamma: [1.]
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.1462e-01 -9.4832e+00  1e+02  4e+00  1e+01  1e+00
#  1: -6.1419e-01 -1.2548e+00  7e+00  7e-01  3e+00  1e+00
#  2: -8.3255e-01 -1.0405e+00  2e+00  2e-01  7e-01  3e-01
#  3: -5.8798e-01 -8.6225e-01  2e+00  2e-01  7e-01  3e-01
#  4: -5.2898e-01 -5.3815e-01  5e-02  6e-03  2e-02  7e-03
#  5: -5.3011e-01 -5.3069e-01  3e-03  4e-04  1e-03  5e-04
#  6: -5.2992e-01 -5.3009e-01  8e-04  8e-05  3e-04  6e-05
#  7: -5.2979e-01 -5.2981e-01  1e-04  1e-05  4e-05  7e-06
#  8: -5.2978e-01 -5.2978e-01  2e-05  2e-06  8e-06  1e-06
#  9: -5.2977e-01 -5.2977e-01  2e-06  2e-07  8e-07  1e-07
# 10: -5.2977e-01 -5.2977e-01  8e-07  7e-08  3e-07  3e-08
# 11: -5.2977e-01 -5.2977e-01  7e-08  7e-09  3e-08  3e-09
# Optimal solution found.
# (transformed) robustness gamma: [0.52977306]
# Solving CQLF for beta= 1.80706607094141  resulted in robustness gamma= [0.52977306]
# first approximation:
# approx P_norm(A) =  0.308271006246824
# u 0:
# sampled P_norm(...expm(...)...) =  1.5819948586708178e-05
# u 1:
# sampled P_norm(...expm(...)...) =  5.951281174782421e-05
# y 0:
# sampled P_norm(...expm(...)...) =  0.38488679588794444
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.001977078603931644
# u 1 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.004507013944707823
# approx rho= 0.6997172274437424
# Iteration 1 of 3: delta=2, beta=2.04522057427474
# Solving CQLF for preconditioning (result may be cached)
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.4890e-01 -9.5479e+00  1e+02  4e+00  1e+01  1e+00
#  1: -6.5222e-01 -1.6033e+00  9e+00  8e-01  3e+00  1e+00
#  2: -8.4224e-01 -1.1004e+00  2e+00  2e-01  6e-01  3e-01
#  3: -6.2108e-01 -9.2713e-01  2e+00  2e-01  7e-01  3e-01
#  4: -5.4011e-01 -5.6758e-01  1e-01  2e-02  6e-02  2e-02
#  5: -5.3112e-01 -5.3277e-01  8e-03  1e-03  3e-03  1e-03
#  6: -5.3022e-01 -5.3070e-01  2e-03  2e-04  8e-04  2e-04
#  7: -5.2983e-01 -5.2989e-01  3e-04  3e-05  1e-04  2e-05
#  8: -5.2978e-01 -5.2979e-01  4e-05  5e-06  2e-05  3e-06
#  9: -5.2977e-01 -5.2977e-01  4e-06  4e-07  1e-06  3e-07
# 10: -5.2977e-01 -5.2977e-01  7e-07  8e-08  3e-07  5e-08
# 11: -5.2977e-01 -5.2977e-01  5e-08  5e-09  2e-08  8e-10
# Optimal solution found.
# (transformed) robustness gamma: [0.52977306]
# Solving CQLF for beta= 2.04522057427474  resulted in robustness gamma= [0.52977306]
# first approximation:
# approx P_norm(A) =  0.30827100582151934
# u 0:
# sampled P_norm(...expm(...)...) =  1.583549951320776e-05
# u 1:
# sampled P_norm(...expm(...)...) =  5.951524341863394e-05
# y 0:
# sampled P_norm(...expm(...)...) =  0.38365111714055405
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.00197357828920984
# u 1 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.004499021889704428
# approx rho= 0.6984700738839195
# Iteration 2 of 3: delta=2, beta=2.30738676209989
# Solving CQLF for preconditioning (result may be cached)
# Preconditioning done. Now solving actual CQLF
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.7281e-01 -9.5931e+00  1e+02  4e+00  1e+01  1e+00
#  1: -6.6925e-01 -1.8666e+00  1e+01  8e-01  3e+00  1e+00
#  2: -8.4996e-01 -1.1236e+00  1e+00  2e-01  6e-01  2e-01
#  3: -6.7449e-01 -9.8565e-01  2e+00  2e-01  6e-01  2e-01
#  4: -5.5291e-01 -6.1198e-01  3e-01  3e-02  1e-01  4e-02
#  5: -5.3214e-01 -5.3469e-01  1e-02  2e-03  5e-03  2e-03
#  6: -5.3036e-01 -5.3095e-01  2e-03  3e-04  9e-04  2e-04
#  7: -5.2994e-01 -5.3011e-01  7e-04  8e-05  3e-04  6e-05
#  8: -5.2985e-01 -5.2994e-01  3e-04  4e-05  1e-04  2e-05
#  9: -5.2978e-01 -5.2979e-01  3e-05  4e-06  1e-05  2e-06
# 10: -5.2977e-01 -5.2978e-01  6e-06  7e-07  2e-06  4e-07
# 11: -5.2977e-01 -5.2977e-01  4e-07  5e-08  2e-07  1e-08
# 12: -5.2977e-01 -5.2977e-01  5e-08  6e-09  2e-08  2e-09
# Optimal solution found.
# (transformed) robustness gamma: [0.52977306]
# Solving CQLF for beta= 2.30738676209989  resulted in robustness gamma= [0.52977306]
# first approximation:
# approx P_norm(A) =  0.308271005813002
# u 0:
# sampled P_norm(...expm(...)...) =  1.579864915085113e-05
# u 1:
# sampled P_norm(...expm(...)...) =  5.927617866897737e-05
# y 0:
# sampled P_norm(...expm(...)...) =  0.3816290080417025
# u 0 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.0019595043023472297
# u 1 combined with y 0:
# sampled P_norm(...expm(...)...) =  0.004466927761873833
# approx rho= 0.6964015207467454
# Results:
# rho (approx.): 0.6997172274437424  for  beta: 1.80706607094141  with robustness gamma: [0.52977306]
# Eccentricity alpha (approx): 1.3422684736389878
# rho (approx.): 0.6984700738839195  for  beta: 2.04522057427474  with robustness gamma: [0.52977306]
# Eccentricity alpha (approx): 1.3429932806851512
# rho (approx.): 0.6964015207467454  for  beta: 2.30738676209989  with robustness gamma: [0.52977306]
# Eccentricity alpha (approx): 1.3444841800730867
# Best rho (approx):  0.6964015207467454
# Exact results:
# interval P_norm(A) =  [0.30827100581300176385, 0.30827100581300281856]
# u 0:
# interval P_norm(...expm(...)) =  [0.0, 0.000016017133525947357953]
# sampled P_norm(...expm(...)) =  1.579864915085113e-05
# u 1:
# interval P_norm(...expm(...)) =  [0.0, 0.000061420257553290724672]
# sampled P_norm(...expm(...)) =  5.927617866897737e-05
# y 0:
# interval P_norm(...expm(...)) =  [0.0, 0.40376603246537445813]
# sampled P_norm(...expm(...)) =  0.3816290080417025
# u 0 combined with y 0:
# interval P_norm(...expm(...)) =  [0.0, 0.0027295442940022951461]
# sampled P_norm(...expm(...)) =  0.0019595043023472297
# u 1 combined with y 0:
# interval P_norm(...expm(...)) =  [0.0, 0.013998885251051973455]
# sampled P_norm(...expm(...)) =  0.004466927761873833
# Overall rho:  [0.30827100581300176385, 0.72884290521451078337]

# %%
result
# Out:
# {'n': 8,
#  'rho': 0.7288429780988014,
#  'rho_approx': 0.6964015207467454,
#  'time': 9.533232,
#  'time_approx': 3.329077}
